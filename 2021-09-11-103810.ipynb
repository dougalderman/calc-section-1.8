# %%
x = var('x')

# %%
y = (sqrt(x) + 1)/(sqrt(x) - 1)

# %%
d = derivative(y, x)

# %%
d
# Out:
# -1/2*(sqrt(x) + 1)/(sqrt(x)*(sqrt(x) - 1)^2) + 1/2/(sqrt(x)*(sqrt(x) - 1))

# %%
d2 = derivative(y, x, 2)

# %%
d2
# Out:
# 1/4*(sqrt(x) + 1)/(x^(3/2)*(sqrt(x) - 1)^2) - 1/4/(x^(3/2)*(sqrt(x) - 1)) + 1/2*(sqrt(x) + 1)/(x*(sqrt(x) - 1)^3) - 1/2/(x*(sqrt(x) - 1)^2)

# %%
t = var('t')

# %%
s = (-t^3+ 3*t)

# %%
v = derivative(f, t)

# %%
v
# Out:
# -3*t^2 + 3

# %%
a = derivative(f, t, 2)

# %%
a
# Out:
# -6*t

# %%
plot(s,(t,-3,3))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(v,(t,-3,3))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(a,(t,-3,3))
# Out:
# Graphics object consisting of 1 graphics primitive
